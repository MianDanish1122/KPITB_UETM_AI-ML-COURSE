# %%
name = "ali"

# %%
print(name)
# Out:
# ali

# %%
name = "danish"

# %%
print(name)
# Out:
# danish

# %%
import numpy as np

# %%
arr = np.array([5,10,15,20,25])

# %%
print(arr)
# Out:
# [ 5 10 15 20 25]

# %%
np.sum(arr)
# Out:
# np.int64(75)

# %%
np.mean(arr)
# Out:
# np.float64(15.0)

# %%
np.max(arr)
# Out:
# np.int64(25)

# %% [markdown]
# **Task_02**

# %%
import pandas as pd

# %%
data = {"name":["Ali","Ahmad", "Sara"],"Age":[20,21,22], "Marks":[85,90,78]}

# %%
data = pd.DataFrame(data)

# %%
print(data)
# Out:
#     name  Age  Marks
# 0    Ali   20     85
# 1  Ahmad   21     90
# 2   Sara   22     78

# %%
print(data["Marks"])
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %% [markdown]
# **Task_03**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/student_perfrom.csv")

# %%
df.head()
# Out:
#    Student_ID  Gender   Age  Study_Hours  Attendance_%  Math_Score  \
# 0           1    Male  18.0          4.0          85.0          78
# 1           2  Female  19.0          6.0          90.0          88
# 2           3    Male  18.0          NaN          70.0          65
# 3           4  Female  20.0          2.0           NaN          45
# 4           5    Male  19.0          5.0          88.0          82
#
#    Science_Score  English_Score Final_Result
# 0           72.0           75.0         Pass
# 1           91.0           87.0         Pass
# 2           60.0           62.0         Pass
# 3           50.0           48.0         Fail
# 4           80.0            NaN         Pass

# %%
df.shape
# Out:
# (20, 9)

# %%
df.isnull().sum()
# Out:
# Student_ID       0
# Gender           0
# Age              2
# Study_Hours      2
# Attendance_%     2
# Math_Score       0
# Science_Score    2
# English_Score    2
# Final_Result     0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.fillna(0)
# Out:
#     Student_ID  Gender   Age  Study_Hours  Attendance_%  Math_Score  \
# 0            1    Male  18.0          4.0          85.0          78
# 1            2  Female  19.0          6.0          90.0          88
# 2            3    Male  18.0          0.0          70.0          65
# 3            4  Female  20.0          2.0           0.0          45
# 4            5    Male  19.0          5.0          88.0          82
# 5            6  Female  18.0          7.0          95.0          92
# 6            7    Male  21.0          1.0          60.0          35
# 7            8  Female   0.0          3.0          75.0          55
# 8            9    Male  20.0          4.0          80.0          70
# 9           10  Female  19.0          6.0          92.0          89
# 10          11    Male  18.0          2.0          65.0          48
# 11          12  Female  21.0          5.0           0.0          75
# 12          13    Male  19.0          3.0          72.0          60
# ...

# %%
df.dropna()
# Out:
#     Student_ID  Gender   Age  Study_Hours  Attendance_%  Math_Score  \
# 0            1    Male  18.0          4.0          85.0          78
# 1            2  Female  19.0          6.0          90.0          88
# 5            6  Female  18.0          7.0          95.0          92
# 6            7    Male  21.0          1.0          60.0          35
# 9           10  Female  19.0          6.0          92.0          89
# 10          11    Male  18.0          2.0          65.0          48
# 13          14  Female  20.0          8.0          98.0          95
# 15          16  Female  18.0          1.0          55.0          30
# 16          17    Male  22.0          6.0          90.0          85
# 18          19    Male  20.0          2.0          60.0          40
#
#     Science_Score  English_Score Final_Result
# 0            72.0           75.0         Pass
# 1            91.0           87.0         Pass
# 5            94.0           90.0         Pass
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['English_Score'].plot(kind = 'hist')
plt.show()

# %%
# !pip uninstall -y pandas_profiling
# !pip install ydata-profiling
# Out:
# Found existing installation: pandas-profiling 3.1.0
# Uninstalling pandas-profiling-3.1.0:
#   Successfully uninstalled pandas-profiling-3.1.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.4/400.4 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 100.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 4.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: multimethod
#     Found existing installation: multimethod 2.0.2
#     Uninstalling multimethod-2.0.2:
#       Successfully uninstalled multimethod-2.0.2
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# ...

# %%
import pandas as pd
df = pd.read_csv("/content/student_perfrom.csv")
from ydata_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.18.1&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2026-01-25 09:07:51.645935&quot; name=date&gt;&lt;title&gt;YData Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...
