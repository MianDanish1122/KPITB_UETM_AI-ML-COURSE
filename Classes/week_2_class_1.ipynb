# %%
import numpy as np

# %%
v1 = np.array([2,3,4])

# %%
v2 = np.array([4,6,8])

# %%
v3 = np.array([5,1,0])

# %%
print("similariy v1 and v2 ", np.dot(v1,v2))
# Out:
# similariy v1 and v2  58

# %%
print("similariy v1 and v3 ", np.dot(v1,v3))
# Out:
# similariy v1 and v3  13
